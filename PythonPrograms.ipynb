# %% [markdown]
# **1**. python program to add 2 numbers

# %%
num1 = 5
num2 = 10
sum = num1+num2
print(sum)
# Out:
# 15

# %% [markdown]
# **2**. Python program to take user input and add two numbers

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")
num1 = int(num1)
num2 = int(num2)
sum = num1+num2
print(sum)
# Out:
# Enter first number: 10
# Enter second number: 40
# 50

# %% [markdown]
# **3**. Python program to implement Simple Calculator

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print("Sum: ",num1+num2)
print("Difference: ",num1-num2)
print("Product: ",num1*num2)
print("Quotient: ",num1/num2)
# Out:
# Enter first number: 10
# Enter second number: 50
# Sum:  60
# Difference:  -40
# Product:  500
# Quotient:  0.2

# %% [markdown]
# 4. **Python** program to enter a word and check its palindrome

# %%
num1 = input("Enter a word: ")
if num1 == num1[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a word: wow
# Palindrome

# %% [markdown]
# **5. Upload image and perform different tasks on it**

# %%
from google.colab import files
from IPython.display import Image, display
from PIL import Image, ImageFilter

# 1. Upload the image
print("Please upload an image:")
uploaded = files.upload()

# 2. Process and display the image
for fn in uploaded.keys():
  # Open the image
  img = Image.open(fn)

  # --- Perform Image Manipulations ---

  # Convert to grayscale
  grayscale_img = img.convert('L')

  # Blur the image more
  blurred_img = img.filter(ImageFilter.BLUR)
  blurred_img = blurred_img.filter(ImageFilter.BLUR)

  # Rotate the image
  rotated_img = img.rotate(90)

  # --- Display the Images ---

  # Set a new width for the displayed images
  display_width = 200

  # Display the images resized
  print("\n--- Image Results ---")
  print("Original Image:")
  w, h = img.size
  display(img.resize((display_width, int(h * display_width / w))))

  print("Grayscale Image:")
  w, h = grayscale_img.size
  display(grayscale_img.resize((display_width, int(h * display_width / w))))

  print("Blurred Image:")
  w, h = blurred_img.size
  display(blurred_img.resize((display_width, int(h * display_width / w))))

  print("Rotated Image:")
  w, h = rotated_img.size
  display(rotated_img.resize((display_width, int(h * display_width / w))))
# Out:
# Please upload an image:
#      <input type="file" id="files-f393b073-4485-4c85-8f84-6e78c18d1929" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f393b073-4485-4c85-8f84-6e78c18d1929">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# **6. Python code for handling video files**

# %%
import cv2
from google.colab import files
import os

# Upload the video file
print("Please upload a video file:")
uploaded = files.upload()
video_path = list(uploaded.keys())[0]

# Create a directory to save the frames
output_folder = 'frames'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Open the video file
cap = cv2.VideoCapture(video_path)
frame_count = 0

# Read and save each frame
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Save the frame as an image
    frame_filename = os.path.join(output_folder, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_filename, frame)

    frame_count += 1

# Release the video capture object
cap.release()

print(f"\nExtraction complete. {frame_count} frames were extracted and saved in the '{output_folder}' directory.")
# Out:
# Please upload a video file:
#      <input type="file" id="files-167d3049-41fe-4f75-b7e2-398637a1c231" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-167d3049-41fe-4f75-b7e2-398637a1c231">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
